# %% [markdown]
# Ссылка на материалы:  [пдф тут](https://drive.google.com/file/d/16Cm2tgrpuDH8eIdxdSYyOsfDPqnJ3byd/view?usp=sharing)

# %% [markdown]
# ФИО:

# %%
Вепрев Никита Сергеевич

# %% [markdown]
# ## Задание 1. HTTP-запросы, ответы и погода

# %% [markdown]
# Описание:
#
# Напишите HTTP-запрос для получения информации о погоде в введенном городе из API.
#
# Можно использовать API: https://open-meteo.com/. Используйте метод GET.
#
#
# Ввод
# ```
# 56.50, 60.35
# ```
#
# Вывод
# ```
# Сегодня (1.11) погода 20 ◦С, нет осадков, туман
# ```

# %%
pip install requests

# %%
# Out:
# 2
# ...

# %% [markdown]
# ## Задание 2. HTTP-запросы, ответы и покемоны

# %% [markdown]
# **Описание:**
#
#
# Создайте код программы, которая будет взаимодействовать с API, со следующим функионалом:
#
# 1. Используя метод GET, отправьте запрос на endpoint /pokemon, чтобы получить список первых 20 покемонов
#
# 2. Извлеките имена покемонов из ответа и выведите их списком
#
# 3. Введите с помощью input() название одного из покемонов
#
#
# ```
# Имя покемона: clefairy
# ```
#
#
#
# 4. Отправьте GET-запрос, чтобы получить полную информацию о выбранном покемоне
#
# 5. Извлеките и выведите следующие данные о введенном покемоне:
#
#      • Имя
#
#      • Тип
#
#      • Вес
#
#      • Рост
#
#      • Способности
#
# Используйте PokéAPI (https://pokeapi.co/), который предоставляет информацию о покемонах, их характеристиках, типах и другую информацию.

# %%
import requests


def send_request(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        return None


def info_pokemons(pokemons):
    if pokemons:
        name = pokemons['name']
        types = [t['type']['name'] for t in pokemons['types']]
        height = pokemons['height']
        weight = pokemons['weight']
        abilities = [a['ability']['name'] for a in pokemons['abilities']]

        message = (
            f"Имя: {name}\n"
            f"Тип: {', '.join(types)}\n"
            f"Вес: {weight}\n"
            f"Рост: {height}\n"
            f"Способности: {', '.join(abilities)}"
        )
        return message
    else:
        return "Ошибка при получении данных о покемоне."


params = input("Введите имя покемона: ")
url = f'https://pokeapi.co/api/v2/pokemon/{params}'
pokemons = send_request(url)

message = info_pokemons(pokemons)
print(message)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c5883aa8ae82> in <cell line: 32>()
#      30
#      31
# ---> 32 params = input("Введите имя покемона: ")
#      33 url = f'https://pokeapi.co/api/v2/pokemon/{params}'
#      34 pokemons = send_request(url)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# ## Задание 3. HTTP-запросы, ответы и посты

# %% [markdown]
# **Описание:**
#
# Создайте программу, которая будет взаимодействовать с JSONPlaceholder API, реализуя следующие функции:
#
# 1. Реализуйте функцию, которая выполняет GET-запрос к https://jsonplaceholder.typicode.com/posts и возвращает список постов в формате JSON
#
# 2. Реализуйте функцию, котороая получает вводимое ID поста, выполняет GET-запрос по ID и возвращает данные поста в формате JSON
#
# 3. Реализуйте функцию, которая выполняет обработку JSON из пункта 2 и выводит всю важную информацию в консоль

# %%
import requests
import json

def get_all_posts():
    url = "https://jsonplaceholder.typicode.com/posts"
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Ошибка при получении списка постов: {e}")
        return None

def get_post_by_id(post_id):
    url = f"https://jsonplaceholder.typicode.com/posts/{post_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Ошибка при получении поста с ID {post_id}: {e}")
        return None
    except json.JSONDecodeError:
        print(f"Ошибка декодирования JSON для поста с ID {post_id}")
        return None


def print_post_info(post_data):
    if post_data:
        print("Информация о посте:")
        print(f" ID: {post_data['id']}")
        print(f" UserID: {post_data['userId']}")
        print(f" Заголовок: {post_data['title']}")
        print(f" Текст: {post_data['body']}")
    else:
        print("Данные о посте отсутствуют.")


if __name__ == "__main__":
    all_posts = get_all_posts()
    if all_posts:
        print("Получен список всех постов")
    post_id = input("Введите ID поста для получения подробной информации: ")
    try:
        post_id = int(post_id)
        post_data = get_post_by_id(post_id)
        print_post_info(post_data)
    except ValueError:
        print("Некорректный формат ID. Введите целое число.")

# %% [markdown]
# ## Задание 4. HTTP-запросы, ответы и работа с постами

# %% [markdown]
# **Описание**
#
# Создайте программу, которая будет взаимодействовать с JSONPlaceholder API (из предыдущего задания), реализуя новые функции:
#
# 1. Реализуйте функцию, которая принимает заголовок, содержимое и ID пользователя (информация вводится с помощью input()), выполняет POST-запрос для создания нового поста и возвращает информацию о созданном посте в формате JSON
#
#
# ```
# Заголовок: Новый пост
# Содержимое поста: Тут должно находиться содержимое нового поста...
# ID пользователя: 10
# ```
#
#
#
# 2. Реализуйте функцию, которая принимает ID поста, новый заголовок и новое содержимое, выполняет PUT-запрос и возвращает обновлённый пост в формате JSON
#
# 3. Реализуйте функцию, которая принимает ID поста, выполняет DELETE-запрос и возвращает статус-код ответа

# %%
import requests
import json

BASE_URL = "https://jsonplaceholder.typicode.com"

def create_post(title, body, userId):
    """Создает новый пост с помощью POST-запроса."""
    url = f"{BASE_URL}/posts"
    data = {"title": title, "body": body, "userId": userId}
    headers = {'Content-type': 'application/json'}
    try:
        response = requests.post(url, json=data, headers=headers)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Ошибка при создании поста: {e}")
        return None
    except json.JSONDecodeError:
        print(f"Ошибка декодирования JSON при создании поста.")
        return None


def update_post(postId, newTitle, newBody):
    """Обновляет пост с помощью PUT-запроса."""
    url = f"{BASE_URL}/posts/{postId}"
    data = {"title": newTitle, "body": newBody}
    headers = {'Content-type': 'application/json'}
    try:
        response = requests.put(url, json=data, headers=headers)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Ошибка при обновлении поста {postId}: {e}")
        return None
    except json.JSONDecodeError:
        print(f"Ошибка декодирования JSON при обновлении поста {postId}.")
        return None


def delete_post(postId):
    """Удаляет пост с помощью DELETE-запроса."""
    url = f"{BASE_URL}/posts/{postId}"
    try:
        response = requests.delete(url)
        response.raise_for_status()
        return response.status_code
    except requests.exceptions.RequestException as e:
        print(f"Ошибка при удалении поста {postId}: {e}")
        return None


if __name__ == "__main__":
    title = input("Введите заголовок поста: ")
    body = input("Введите текст поста: ")
    try:
        userId = int(input("Введите ID пользователя: "))
        new_post = create_post(title, body, userId)
        if new_post:
            print("Созданный пост:")
            print(json.dumps(new_post, indent=2))
    except ValueError:
        print("Некорректный ID пользователя. Введите целое число.")

    try:
        postId = int(input("\nВведите ID поста для обновления: "))
        newTitle = input("Введите новый заголовок: ")
        newBody = input("Введите новый текст: ")
        updated_post = update_post(postId, newTitle, newBody)
        if updated_post:
            print("\nОбновлённый пост:")
            print(json.dumps(updated_post, indent=2))
    except ValueError:
        print("Некорректный ID поста. Введите целое число.")
    try:
        postId = int(input("\nВведите ID поста для удаления: "))
        status_code = delete_post(postId)
        if status_code == 200:
            print(f"\nПост {postId} успешно удалён (статус код: {status_code})")
        elif status_code:
            print(f"\nОшибка при удалении поста {postId} (статус код: {status_code})")

    except ValueError:
        print("Некорректный ID поста. Введите целое число.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2c9d71b45a50> in <cell line: 52>()
#      51
#      52 if __name__ == "__main__":
# ---> 53     title = input("Введите заголовок поста: ")
#      54     body = input("Введите текст поста: ")
#      55     try:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# ## Задание 5. HTTP-запросы, ответы и пёсики

# %% [markdown]
# **Описание**
#
# Создайте программу, которая будет взаимодействовать с Dog API, которая позволит получать список пород собак, вводить несколько пород и получать их фотогрфии.
#
# Этапы:
#
# 1. Создайте функцию, которая использует метод GET и возвращает список всех пород собак в формате нумерованного списка
#
# 2. Реализуйте возможность ввода нескольких пород собак через запятую
#
#
# ```
# african, chow, dingo
# ```
#
#
#
# 3. Создание функции, которая реализует запрос, возвращает и выводит изображениия собак, породы которых были введены до этого
#
#
# Используйте Dog API (https://dog.ceo/dog-api/), который предоставляет информацию о породах собак и их изображения.

# %% [markdown]
# *Подсказка*
#
#
#
# ```
# import requests
# from PIL import Image
# from IPython.display import display
# import io
#
# url = <____>
# response = <____>
#
# if response.<______> == <___>:
#       image_url = response.json()['message']
#
# res = requests.<__>(image_url)
# img = Image.open(io.BytesIO(res.content))
# display(img)
# ```
